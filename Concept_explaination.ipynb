# %% [markdown]
# # Problem Statement::

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ## DATA::

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ## Solution::
# ## Method-1 --->Without Using Randomized Block design Approach::

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# # So here since
#                 p-value = 0.000176 < alpha=0.01
#                 SO WE REJECT THE NULL HYPOTHESIS(all means are equal).

# %% [markdown]
# # Method-2:: Using the Randomized Block Approach.

# %% [markdown]
# ## STEP-1

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# ## STEP-2

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# ## STEP-3

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# ## STEP-4

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# # HERE ALSO WE HAVE REJECTED THE NULL HYPOTHESIS ---- using the blocking approach.
